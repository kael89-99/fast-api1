# %% [markdown]
# <a href="https://colab.research.google.com/github/kael89-99/fast-api1/blob/main/statements_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Learning Statements

# %%
print('test1')
# Out:
# test1

# %% [markdown]
# ###variables

# %%
variabl = 7

# %% [markdown]
# ### Data Structures

# %% [markdown]
# ####List

# %%
my_list = [1,3,7,9]

# %%
my_list[2]
# Out:
# 7
